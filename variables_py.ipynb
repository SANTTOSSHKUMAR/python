# %% [markdown]
# <a href="https://colab.research.google.com/github/SANTTOSSHKUMAR/python/blob/coreexamples/variables_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
var_1 = 5000


var_2 = 2000.8


var_1 + var_2,
var_1,
var_2,
type(var_2)
# Out:
# float
